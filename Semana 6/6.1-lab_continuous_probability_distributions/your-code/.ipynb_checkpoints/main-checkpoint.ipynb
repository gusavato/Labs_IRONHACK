# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Before-your-start:" data-toc-modified-id="Before-your-start:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Before your start:</a></span><ul class="toc-item"><li><span><a href="#Uniform-Distribution" data-toc-modified-id="Uniform-Distribution-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Uniform Distribution</a></span></li><li><span><a href="#Normal-Distribution" data-toc-modified-id="Normal-Distribution-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Normal Distribution</a></span></li><li><span><a href="#Normal-Distribution-of-Real-Data" data-toc-modified-id="Normal-Distribution-of-Real-Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Normal Distribution of Real Data</a></span></li><li><span><a href="#Exponential-Distribution" data-toc-modified-id="Exponential-Distribution-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Exponential Distribution</a></span></li><li><span><a href="#Exponential-Distribution-of-Real-Data" data-toc-modified-id="Exponential-Distribution-of-Real-Data-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Exponential Distribution of Real Data</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
import pandas as pd

from scipy.stats import uniform, norm, expon

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.29931033 2.76164876 2.08133982 2.55270993 2.37686135 2.19543574
#  2.04697273 2.97396247 2.39472685 2.31750795]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
def rand_uni(bottom=0,ceiling=1,count=10):
    x = uniform.rvs(size=count)
    randoms  = bottom + (ceiling-bottom)*x
    return randoms

dist_1 = rand_uni(10,15,100)
dist_2 = rand_uni(10,60,1000)

fig = make_subplots(rows=1,cols=2,shared_yaxes=True)
fig.add_trace(go.Histogram(x=dist_1,nbinsx=10),row=1,col=1)
fig.add_trace(go.Histogram(x=dist_2,nbinsx=10),row=1,col=2)
fig.update_layout(showlegend=False)
# Out:
# <div>                            <div id="250ebb85-53c5-413d-a106-1b10d3f08039" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("250ebb85-53c5-413d-a106-1b10d3f08039")) {                    Plotly.newPlot(                        "250ebb85-53c5-413d-a106-1b10d3f08039",                        [{"nbinsx":10,"x":[11.509025798614749,10.184595622946304,11.843498651957358,13.4462008748026,12.028085886618685,14.293484740218968,14.6135849469686,11.774271811793122,11.159998385350324,11.004776505281427,10.717295275271539,13.582354901506264,10.345887039083351,11.498132738543392,10.32659505920973,10.437842333137926,11.11727656865834,13.419688653348633,11.867228926773937,13.753712620125171,12.096537586778144,11.043937971501348,11.415183757444611,12.514107500583224
# ...

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
# Las dos distribuciones son similares, ya que todos los valores se distribuyen equitativamente, la diferencia significativa 
# es que una tiene muchos más valores que la otra

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here
def create_norm(mean=0,std=1,count=100):
    return norm(loc=mean,scale=std).rvs(count)

dist_1 = create_norm(10,1,1000)
dist_2 = create_norm(10,50,1000)

fig = make_subplots(rows=2,cols=1)
fig.add_trace(go.Histogram(x=dist_1,nbinsx=500),row=1,col=1)
fig.add_trace(go.Histogram(x=dist_2,nbinsx=500),row=2,col=1)
fig.update_layout(showlegend=False)
# Out:
# <div>                            <div id="7a3541aa-e32c-4254-a0da-624836f5c5a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a3541aa-e32c-4254-a0da-624836f5c5a3")) {                    Plotly.newPlot(                        "7a3541aa-e32c-4254-a0da-624836f5c5a3",                        [{"nbinsx":500,"x":[9.439550610978506,8.873547289966888,10.090995716090008,9.93978410143895,11.664740319522224,9.176930933095958,10.252916234665449,10.013144206712985,10.08149787818536,10.186556515329563,10.850623704811646,9.655553593117144,10.119127650837115,10.894236982511522,9.477608340429605,8.278656763755803,10.83229601996968,9.29311797023932,8.974522936238165,10.110989487696848,8.80143607116317,9.090725760099854,8.718969904314728,10.96025416362512,10.6037697
# ...

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
# La diferencia entre desviaciones típicas hacer que los datos en la segunda distribución estén repartidos entre un rango de -100 y 150 (aprox), mientras
# que en la primera están repartidos en tre 8 y 12

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
vehicles = pd.read_csv('vehicles.csv')
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5  \
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD  \
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG
# ...

# %%
px.histogram(x=vehicles['Fuel Barrels/Year'],nbins=200)
# Out:
# <div>                            <div id="c0de0a2b-6140-46f5-9b8f-ae1c988c6e2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0de0a2b-6140-46f5-9b8f-ae1c988c6e2c")) {                    Plotly.newPlot(                        "c0de0a2b-6140-46f5-9b8f-ae1c988c6e2c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":200,"offsetgroup":"","orientation":"v","showlegend":false,"x":[19.388823529411766,25.35461538461539,20.600625,25.35461538461539,20.600625,14.98227272727273,13.73375,16.4805,14.98227272727273,13.73375,16.4805,14.98227272727273,13.73375,16.4805,16.4805,16.4805,17.347894736842107,16.4805
# ...

# %%
# your code here
px.histogram(vehicles['CO2 Emission Grams/Mile'],nbins=500).update_layout(showlegend=False)
# Out:
# <div>                            <div id="0c3d4692-fc42-48fd-ae9c-47082b01ea14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c3d4692-fc42-48fd-ae9c-47082b01ea14")) {                    Plotly.newPlot(                        "0c3d4692-fc42-48fd-ae9c-47082b01ea14",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=CO2 Emission Grams/Mile<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"CO2 Emission Grams/Mile","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CO2 Emission Grams/Mile","nbinsx":500,"offsetgroup":"CO2 Emission Grams/Mile","orientation":"v","showlegend":true,"x":[522.7647058823529,683.6153846153846,555.4375,683.6153846153846,555.4375,403.95454545454544,370.29166666666674,444.
# ...

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
px.histogram(x=vehicles['Combined MPG'],nbins=60)
# Out:
# <div>                            <div id="d0afcd5c-3423-4594-89be-cbdf6839cf28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0afcd5c-3423-4594-89be-cbdf6839cf28")) {                    Plotly.newPlot(                        "d0afcd5c-3423-4594-89be-cbdf6839cf28",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":60,"offsetgroup":"","orientation":"v","showlegend":false,"x":[17,13,16,13,16,22,24,20,22,24,20,22,24,20,20,20,19,20,19,20,19,20,21,20,21,20,20,20,21,21,19,19,19,18,18,18,18,18,18,28,25,28,25,28,25,29,29,38,38,24,25,24,25,24,25,24,25,22,23,23,23,23,23,24,23,23,25,24,24,25,24,24,25,25,2
# ...

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here
# Las tres parecen seguir una distribución normal. La variable Combined MPG parece ser más asimétrica

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
dist_1 = expon(scale=10).rvs(100)
dist_2 = expon(scale=100).rvs(100)

fig = make_subplots(rows=1,cols=2,shared_yaxes=True)
fig.add_trace(go.Histogram(x=dist_1,nbinsx=100),row=1,col=1)
fig.add_trace(go.Histogram(x=dist_2,nbinsx=100),row=1,col=2)
fig.update_layout(showlegend=False)
# Out:
# <div>                            <div id="f3685432-a407-4aa0-a0d2-407ef76fae9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3685432-a407-4aa0-a0d2-407ef76fae9b")) {                    Plotly.newPlot(                        "f3685432-a407-4aa0-a0d2-407ef76fae9b",                        [{"nbinsx":100,"x":[6.59543196808451,5.2592051284930195,1.5835721415679582,29.099333097202805,9.557942811624361,1.700497846091464,4.965244292183981,6.933326559342725,10.429029581624938,5.351000045181314,5.190666757186342,4.83130938191279,0.4341647478301792,6.739837174228333,3.338919726478669,0.9510552488252186,8.063102375237218,37.13654892225898,6.31196527945372,33.0162870498519,6.952355107346969,8.131070837707174,13.766242874248135,11.833609042781305,2.0916220524
# ...

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)

expon(scale=10).cdf(15)
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here

# %%
1 - expon(scale=10).cdf(15)
# Out:
# 0.2231301601484298
